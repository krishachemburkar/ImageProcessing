# %% [markdown]
# ##***SIP LAB 3***
#
# Krisha Chemburkar
#
# I012
#
# B1 Batch
#
# Semester IV
#
# BTech AI

# %% [markdown]
# # ***Aim:***
#
# a. Apply grayscale resolution on the test image to obtain new image.
#
#     i. Calculate the compression ratio between the test image and new image
#
#     ii. Comment on subjective quality of the image for various levels of grayscale resolution
#
# b. Apply sampling resolution on the test image to obtain the new image.
#
#     i. Calculate the compression ratio between the test image and new image
#
#     ii. Comment on subjective quality of the image for various down sampling rates

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### ***Apply grayscale resolution on the test image to obtain new image***

# %% [markdown]
# s= (2b-1/2k-1)∗r
#
# where,
# * b=old bits
# * k=new bits

# %%
img1 = cv2.imread('/content/cameraman.tif',0) #reading the image
type(img1)
# Out:
# numpy.ndarray

# %%
np.max(img1) #finding the maximum pixel value
# Out:
# 255

# %%
[m,n]= img1.shape #stores the shape of the image

# %%
k = int(input("Enter no. of required bits for the new image = "))
# Out:
# Enter no. of required bits for the new image = 3

# %%
original = 256 #2^8
new = (2**k)-1
Constant = new/(original-1)
Constant
# Out:
# 0.027450980392156862

# %%
#Changing bits
img1_gr= np.zeros((m,n),dtype= np.int)

for i in range(m):
  for j in range(n):

    img1_gr[i][j] = Constant*img1[i][j]

# %%
img1_gr
# Out:
# array([[4, 4, 4, ..., 4, 4, 4],
#        [4, 4, 4, ..., 4, 4, 4],
#        [4, 4, 4, ..., 4, 4, 4],
#        ...,
#        [3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3],
#        [3, 3, 3, ..., 3, 3, 3]])

# %%
#Plotting and comparing both the images
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(img1,cmap ='gray')
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(img1_gr,cmap ='gray')
plt.title('Reduced Grayscale Resolution')
# Out:
# Text(0.5, 1.0, 'Reduced Grayscale Resolution')

# %%
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(img1)
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(img1_gr)
plt.title('Reduced Resolution')
# Out:
# Text(0.5, 1.0, 'Reduced Resolution')

# %% [markdown]
# ### ***Apply sampling resolution on the test image to obtain the new image***

# %%
print("Shape of original image:", img1.shape)
# Out:
# Shape of original image: (512, 512)

# %%
rate = int(input("enter the down sampling rate: ")) #factor to downsize
# Out:
# enter the down sampling rate: 16

# %%
img1_ds = img1[::rate,::rate]  #slicing the image

# %%
print("Shape of downsized image:", img1_ds.shape)
# Out:
# Shape of downsized image: (32, 32)

# %%
#Plotting and comparing the original and the downsized image
plt.figure(figsize=(8,8))
plt.subplot(1,2,1)
plt.imshow(img1, cmap ='gray')
plt.title('Original')
plt.subplot(1,2,2)
plt.imshow(img1_ds, cmap ='gray')
plt.title('Downsized')
# Out:
# Text(0.5, 1.0, 'Downsized')

# %% [markdown]
# ### ***Conclusion***
#
# In this experiment, we did the tasks of reducing grayscale resolution and downsizing the image respectively.
#
# In reducing the grayscale resolution we see that there is patches of colours and disturbance in the image compared to the original one.
#
# In downsizing we see that the image looks pixelated because of we remove certain rows and columns.
